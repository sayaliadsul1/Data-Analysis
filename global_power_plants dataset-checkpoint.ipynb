# %%
# 5/4/22

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\Acer\Desktop\My Work\NumPy(pdf)\global_power_plants.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13620/1965373530.py in <module>
# ----> 1 dataset=pd.read_csv(r"C:\Users\Acer\Desktop\My Work\NumPy(pdf)\global_power_plants.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13620/48412968.py in <module>
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country code                   34936 non-null  object
#  1   country                        34936 non-null  object
#  2   name of powerplant             34936 non-null  object
#  3   capacity in MW                 34936 non-null  object
#  4   latitude                       34936 non-null  float64
#  5   longitude                      34936 non-null  float64
#  6   primary_fuel                   34936 non-null  object
#  7   secondary fuel                 1944 non-null   object
#  8   other_fuel 1                   276 non-null    object
#  9   other_fuel 2                   92 non-null     object
#  10  start date                     17447 non-null  float64
#  11  owner of plant                 20868 non-null  object
# ...

# %%
dataset.count()
# Out:
# country code                     34936
# country                          34936
# name of powerplant               34936
# capacity in MW                   34936
# latitude                         34936
# longitude                        34936
# primary_fuel                     34936
# secondary fuel                    1944
# other_fuel 1                       276
# other_fuel 2                        92
# start date                       17447
# owner of plant                   20868
# geolocation_source               34517
# generation_gwh_2020               9659
# generation_data_source           11400
# estimated_generation_gwh_2020    33138
# dtype: int64

# %%
dataset["country"]
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 34931         Zambia
# 34932         Zambia
# 34933         Zambia
# 34934       Zimbabwe
# 34935       Zimbabwe
# Name: country, Length: 34936, dtype: object

# %%
ad=dataset["capacity in MW"]

# %%
ad
# Out:
# 0         $ 33
# 1           10
# 2           10
# 3           66
# 4          100
#          ...
# 34931     50.0
# 34932     20.0
# 34933    108.0
# 34934    920.0
# 34935    750.0
# Name: capacity in MW, Length: 34936, dtype: object

# %%
dataset[["country code","country","capacity in MW","primary_fuel"]]
# Out:
#       country code      country capacity in MW primary_fuel
# 0              AFG  Afghanistan           $ 33        Hydro
# 1              AFG  Afghanistan             10        Solar
# 2              AFG  Afghanistan             10        Solar
# 3              AFG  Afghanistan             66        Hydro
# 4              AFG  Afghanistan            100        Hydro
# ...            ...          ...            ...          ...
# 34931          ZMB       Zambia           50.0          Oil
# 34932          ZMB       Zambia           20.0          Oil
# 34933          ZMB       Zambia          108.0        Hydro
# 34934          ZWE     Zimbabwe          920.0         Coal
# 34935          ZWE     Zimbabwe          750.0        Hydro
#
# [34936 rows x 4 columns]

# %%
ab=dataset[["country code","country","capacity in MW","primary_fuel"]]

# %%
ab
# Out:
#       country code      country capacity in MW primary_fuel
# 0              AFG  Afghanistan           $ 33        Hydro
# 1              AFG  Afghanistan             10        Solar
# 2              AFG  Afghanistan             10        Solar
# 3              AFG  Afghanistan             66        Hydro
# 4              AFG  Afghanistan            100        Hydro
# ...            ...          ...            ...          ...
# 34931          ZMB       Zambia           50.0          Oil
# 34932          ZMB       Zambia           20.0          Oil
# 34933          ZMB       Zambia          108.0        Hydro
# 34934          ZWE     Zimbabwe          920.0         Coal
# 34935          ZWE     Zimbabwe          750.0        Hydro
#
# [34936 rows x 4 columns]

# %%
ab.to_csv("Data1.csv",index=False)

# %%
data=pd.read_csv("Data1.csv")

# %%
data
# Out:
#       country code      country capacity in MW primary_fuel
# 0              AFG  Afghanistan           $ 33        Hydro
# 1              AFG  Afghanistan             10        Solar
# 2              AFG  Afghanistan             10        Solar
# 3              AFG  Afghanistan             66        Hydro
# 4              AFG  Afghanistan            100        Hydro
# ...            ...          ...            ...          ...
# 34931          ZMB       Zambia           50.0          Oil
# 34932          ZMB       Zambia           20.0          Oil
# 34933          ZMB       Zambia          108.0        Hydro
# 34934          ZWE     Zimbabwe          920.0         Coal
# 34935          ZWE     Zimbabwe          750.0        Hydro
#
# [34936 rows x 4 columns]

# %%
dataset.head()
# Out:
#   country code      country                                name of powerplant  \
# 0          AFG  Afghanistan      Kajaki Hydroelectric Power Plant Afghanistan
# 1          AFG  Afghanistan                                      Kandahar DOG
# 2          AFG  Afghanistan                                      Kandahar JOL
# 3          AFG  Afghanistan     Mahipar Hydroelectric Power Plant Afghanistan
# 4          AFG  Afghanistan  Naghlu Dam Hydroelectric Power Plant Afghanistan
#
#   capacity in MW  latitude  longitude primary_fuel secondary fuel  \
# 0           $ 33    32.322    65.1190        Hydro            NaN
# 1             10    31.670    65.7950        Solar            NaN
# 2             10    31.623    65.7920        Solar            NaN
# 3             66    34.556    69.4787        Hydro            NaN
# 4            100    34.641    69.7170        Hydro            NaN
#
#   other_fuel 1 other_fuel 2  start date owner of plant geolocation_source  \
# ...

# %%
dataset.tail()
# Out:
#       country code   country  \
# 34931          ZMB    Zambia
# 34932          ZMB    Zambia
# 34933          ZMB    Zambia
# 34934          ZWE  Zimbabwe
# 34935          ZWE  Zimbabwe
#
#                                       name of powerplant capacity in MW  \
# 34931                                              Ndola           50.0
# 34932                                              Nkana           20.0
# 34933                                     Victoria Falls          108.0
# 34934                   Hwange Coal Power Plant Zimbabwe          920.0
# 34935  Kariba Dam South Hydroelectric Power Station Z...          750.0
#
#        latitude  longitude primary_fuel secondary fuel other_fuel 1  \
# 34931  -12.9667    28.6333          Oil            NaN          NaN
# 34932  -12.8167    28.2000          Oil            NaN          NaN
# 34933  -17.9167    25.8500        Hydro            NaN          NaN
# 34934  -18.3835    26.4700         Coal            NaN          NaN
# ...

# %%
dataset["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antarctica',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Bangladesh', 'Belarus', 'Belgium', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Central African Republic', 'Chile', 'China', 'Colombia', 'Congo',
#        'Costa Rica', 'Cote DIvoire', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Fiji', 'Finland', 'France', 'French Guiana', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Honduras', 'Hungary',
# ...

# %%
dataset["country"].nunique()
# Out:
# 167

# %%
dataset["primary_fuel"].unique()
# Out:
# array(['Hydro', 'Solar', 'Gas', 'Other', 'Oil', 'Wind', 'Nuclear', 'Coal',
#        'Waste', 'Biomass', 'Wave and Tidal', 'Petcoke', 'Geothermal',
#        'Storage', 'Cogeneration'], dtype=object)

# %%
dataset["primary_fuel"].nunique()
# Out:
# 15

# %% [markdown]
# # loc function

# %%
dataset.loc[dataset["country"]=="Afghanistan"]
# Out:
#   country code      country  \
# 0          AFG  Afghanistan
# 1          AFG  Afghanistan
# 2          AFG  Afghanistan
# 3          AFG  Afghanistan
# 4          AFG  Afghanistan
# 5          AFG  Afghanistan
# 6          AFG  Afghanistan
# 7          AFG  Afghanistan
# 8          AFG  Afghanistan
#
#                                   name of powerplant capacity in MW  latitude  \
# 0       Kajaki Hydroelectric Power Plant Afghanistan           $ 33   32.3220
# 1                                       Kandahar DOG             10   31.6700
# 2                                       Kandahar JOL             10   31.6230
# 3      Mahipar Hydroelectric Power Plant Afghanistan             66   34.5560
# 4   Naghlu Dam Hydroelectric Power Plant Afghanistan            100   34.6410
# 5  Nangarhar (Darunta) Hydroelectric Power Plant ...          11.55   34.4847
# 6            Northwest Kabul Power Plant Afghanistan             42   34.5638
# ...

# %%
dataset.loc[dataset["country"]=="India"]
# Out:
#       country code country        name of powerplant capacity in MW  latitude  \
# 14052          IND   India          ACME Solar Tower            2.5   28.1839
# 14053          IND   India       ADITYA CEMENT WORKS             98   24.7663
# 14054          IND   India  AES Saurashtra Windfarms           39.2   21.9038
# 14055          IND   India               AGARTALA GT            135   23.8712
# 14056          IND   India              AKALTARA TPP           1800   21.9603
# ...            ...     ...                       ...            ...       ...
# 15636          IND   India                  Yellapur             50   14.9750
# 15637          IND   India               ZAWAR MINES             80   24.3500
# 15638          IND   India                Zaheerabad             50   17.6590
# 15639          IND   India              Zaheerabad 2             10   17.6540
# 15640          IND   India   iEnergy Theni Wind Farm           16.5    9.9344
#
# ...

# %%
dataset.loc[dataset["primary_fuel"]=="Solar",["country","name of powerplant"]]
# Out:
#            country  name of powerplant
# 1      Afghanistan        Kandahar DOG
# 2      Afghanistan        Kandahar JOL
# 17         Algeria               Adrar
# 18         Algeria            Ain Azel
# 20         Algeria        Ain Sekhouna
# ...            ...                 ...
# 34833      Vietnam      Ninh Thuận CMX
# 34847      Vietnam           Phước Nam
# 34894      Vietnam  Thua Thien Hue TTC
# 34895      Vietnam           Thuan Bac
# 34921       Zambia               Kafue
#
# [10665 rows x 2 columns]

# %%
dataset.loc[(dataset['country']=='Afghanistan')&(dataset['estimated_generation_gwh_2020']<=100)]
# Out:
#   country code      country  \
# 1          AFG  Afghanistan
# 2          AFG  Afghanistan
# 5          AFG  Afghanistan
# 7          AFG  Afghanistan
# 8          AFG  Afghanistan
#
#                                   name of powerplant capacity in MW  latitude  \
# 1                                       Kandahar DOG             10   31.6700
# 2                                       Kandahar JOL             10   31.6230
# 5  Nangarhar (Darunta) Hydroelectric Power Plant ...          11.55   34.4847
# 7  Pul-e-Khumri Hydroelectric Power Plant Afghani...              6   35.9416
# 8   Sarobi Dam Hydroelectric Power Plant Afghanistan             22   34.5865
#
#    longitude primary_fuel secondary fuel other_fuel 1 other_fuel 2  \
# 1    65.7950        Solar            NaN          NaN          NaN
# 2    65.7920        Solar            NaN          NaN          NaN
# 5    70.3633        Hydro            NaN          NaN          NaN
# ...

# %%
dataset
# Out:
#       country code      country  \
# 0              AFG  Afghanistan
# 1              AFG  Afghanistan
# 2              AFG  Afghanistan
# 3              AFG  Afghanistan
# 4              AFG  Afghanistan
# ...            ...          ...
# 34931          ZMB       Zambia
# 34932          ZMB       Zambia
# 34933          ZMB       Zambia
# 34934          ZWE     Zimbabwe
# 34935          ZWE     Zimbabwe
#
#                                       name of powerplant capacity in MW  \
# 0           Kajaki Hydroelectric Power Plant Afghanistan           $ 33
# 1                                           Kandahar DOG             10
# 2                                           Kandahar JOL             10
# 3          Mahipar Hydroelectric Power Plant Afghanistan             66
# 4       Naghlu Dam Hydroelectric Power Plant Afghanistan            100
# ...                                                  ...            ...
# ...

# %%
dataset.loc[((dataset["primary_fuel"]=="Hydro")&(dataset["primary_fuel"]=="Solar"))&((dataset["country"]=="Afghanistan")&(dataset["country"]=="India"))]
# Out:
# Empty DataFrame
# Columns: [country code, country, name of powerplant, capacity in MW, latitude, longitude, primary_fuel, secondary fuel, other_fuel 1, other_fuel 2, start date, owner of plant, geolocation_source, generation_gwh_2020, generation_data_source, estimated_generation_gwh_2020]
# Index: []

# %%
dataset.loc[((dataset["primary_fuel"]=="Hydro")|(dataset["primary_fuel"]=="Solar"))&((dataset["country"]=="Afghanistan")|(dataset["country"]=="India"))]
# Out:
#       country code      country  \
# 0              AFG  Afghanistan
# 1              AFG  Afghanistan
# 2              AFG  Afghanistan
# 3              AFG  Afghanistan
# 4              AFG  Afghanistan
# ...            ...          ...
# 15633          IND        India
# 15634          IND        India
# 15636          IND        India
# 15638          IND        India
# 15639          IND        India
#
#                                      name of powerplant capacity in MW  \
# 0          Kajaki Hydroelectric Power Plant Afghanistan           $ 33
# 1                                          Kandahar DOG             10
# 2                                          Kandahar JOL             10
# 3         Mahipar Hydroelectric Power Plant Afghanistan             66
# 4      Naghlu Dam Hydroelectric Power Plant Afghanistan            100
# ...                                                 ...            ...
# 15633                                    Yapaladinni II              5
# ...

# %%
dataset.loc[(dataset['primary_fuel']=='Hydro'),'country':'primary_fuel']
# Out:
#            country                                 name of powerplant  \
# 0      Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 3      Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4      Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 5      Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 7      Afghanistan  Pul-e-Khumri Hydroelectric Power Plant Afghani...
# ...            ...                                                ...
# 34922       Zambia                                        Kafue Gorge
# 34923       Zambia                                             Kariba
# 34927       Zambia                                           Lusiwasi
# 34933       Zambia                                     Victoria Falls
# 34935     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
#       capacity in MW  latitude  longitude primary_fuel
# 0               $ 33   32.3220    65.1190        Hydro
# ...

# %%
dataset.loc[(dataset["primary_fuel"]=="Hydro"),("country code","country","capacity in MW")]
# Out:
#       country code      country capacity in MW
# 0              AFG  Afghanistan           $ 33
# 3              AFG  Afghanistan             66
# 4              AFG  Afghanistan            100
# 5              AFG  Afghanistan          11.55
# 7              AFG  Afghanistan              6
# ...            ...          ...            ...
# 34922          ZMB       Zambia          990.0
# 34923          ZMB       Zambia          930.0
# 34927          ZMB       Zambia           12.0
# 34933          ZMB       Zambia          108.0
# 34935          ZWE     Zimbabwe          750.0
#
# [7156 rows x 3 columns]

# %%
dataset
# Out:
#       country code      country  \
# 0              AFG  Afghanistan
# 1              AFG  Afghanistan
# 2              AFG  Afghanistan
# 3              AFG  Afghanistan
# 4              AFG  Afghanistan
# ...            ...          ...
# 34931          ZMB       Zambia
# 34932          ZMB       Zambia
# 34933          ZMB       Zambia
# 34934          ZWE     Zimbabwe
# 34935          ZWE     Zimbabwe
#
#                                       name of powerplant capacity in MW  \
# 0           Kajaki Hydroelectric Power Plant Afghanistan           $ 33
# 1                                           Kandahar DOG             10
# 2                                           Kandahar JOL             10
# 3          Mahipar Hydroelectric Power Plant Afghanistan             66
# 4       Naghlu Dam Hydroelectric Power Plant Afghanistan            100
# ...                                                  ...            ...
# ...

# %%
dataset.loc[((dataset["primary_fuel"]=="Hydro")|(dataset["primary_fuel"]=="Solar"))&(dataset["longitude"]<=60)]
# Out:
#       country code   country  \
# 9              ALB   Albania
# 10             ALB   Albania
# 11             ALB   Albania
# 12             ALB   Albania
# 13             ALB   Albania
# ...            ...       ...
# 34922          ZMB    Zambia
# 34923          ZMB    Zambia
# 34927          ZMB    Zambia
# 34933          ZMB    Zambia
# 34935          ZWE  Zimbabwe
#
#                                       name of powerplant capacity in MW  \
# 9                                             Bistrica 1             27
# 10                                                Fierza            500
# 11                                                 Koman            600
# 12                                            Lanabregas              5
# 13                                               Shkopet             24
# ...                                                  ...            ...
# 34922                                        Kafue Gorge          990.0
# ...

# %%
dataset.loc[((dataset["primary_fuel"]=="Hydro")|(dataset["primary_fuel"]=="Solar"))&((dataset["longitude"]<=60)|(dataset["country"]=="India"))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13620/4272717115.py in <module>
# ----> 1 dataset.loc[((dataset["primary_fuel"]=="Hydro")|(dataset["primary_fuel"]=="Solar"))&((dataset["longitude"]<=60)|(dataset["country"]=="India"))]
#
# NameError: name 'dataset' is not defined

# %%
# part 4

# %%
dataset
# Out:
#       country code      country  \
# 0              AFG  Afghanistan
# 1              AFG  Afghanistan
# 2              AFG  Afghanistan
# 3              AFG  Afghanistan
# 4              AFG  Afghanistan
# ...            ...          ...
# 34931          ZMB       Zambia
# 34932          ZMB       Zambia
# 34933          ZMB       Zambia
# 34934          ZWE     Zimbabwe
# 34935          ZWE     Zimbabwe
#
#                                       name of powerplant capacity in MW  \
# 0           Kajaki Hydroelectric Power Plant Afghanistan           $ 33
# 1                                           Kandahar DOG             10
# 2                                           Kandahar JOL             10
# 3          Mahipar Hydroelectric Power Plant Afghanistan             66
# 4       Naghlu Dam Hydroelectric Power Plant Afghanistan            100
# ...                                                  ...            ...
# ...
