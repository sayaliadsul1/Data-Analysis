# %%
import numpy as np
import pandas as pd

# %%
heart = pd.read_csv(r"C:\Users\Kajal\Desktop\ssd\Desktop\dataset work November\datasets\heart.csv")
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # 1. unique = indicates all unique values in particular column

# %%
uni1 = heart["Sex"].unique()
print(uni1)
print("-------------------------------------")
print("Sex columns unique values are::",uni1)
# Out:
# ['M' 'F']
# -------------------------------------
# Sex columns unique values are:: ['M' 'F']

# %%
uni2 = heart["ChestPainType"].unique()
print(uni2)
print("---------------------------------------------------")
print("ChestPainType columns unique values are::",uni2)
# Out:
# ['ATA' 'NAP' 'ASY' 'TA']
# ---------------------------------------------------
# ChestPainType columns unique values are:: ['ATA' 'NAP' 'ASY' 'TA']

# %%
uni3 = heart["RestingBP"].unique()
print("RestingBP columns unique values are::")
print("------------------------------------------------------------------------")
print(uni3)
# Out:
# RestingBP columns unique values are::
# ------------------------------------------------------------------------
# [140 160 130 138 150 120 110 136 115 100 124 113 125 145 112 132 118 170
#  142 190 135 180 108 155 128 106  92 200 122  98 105 133  95  80 137 185
#  165 126 152 116   0 144 154 134 104 139 131 141 178 146 158 123 102  96
#  143 172 156 114 127 101 174  94 148 117 192 129 164]

# %%
uni4 = heart["Cholesterol"].unique()
print("Cholesterol columns unique values are::")
print("------------------------------------------------------------------------")
print(uni4)
# Out:
# Cholesterol columns unique values are::
# ------------------------------------------------------------------------
# [289 180 283 214 195 339 237 208 207 284 211 164 204 234 273 196 201 248
#  267 223 184 288 215 209 260 468 188 518 167 224 172 186 254 306 250 177
#  227 230 294 264 259 175 318 216 340 233 205 245 194 270 213 365 342 253
#  277 202 297 225 246 412 265 182 218 268 163 529 100 206 238 139 263 291
#  229 307 210 329 147  85 269 275 179 392 466 129 241 255 276 282 338 160
#  156 272 240 393 161 228 292 388 166 247 331 341 243 279 198 249 168 603
#  159 190 185 290 212 231 222 235 320 187 266 287 404 312 251 328 285 280
#  192 193 308 219 257 132 226 217 303 298 256 117 295 173 315 281 309 200
#  336 355 326 171 491 271 274 394 221 126 305 220 242 347 344 358 169 181
#    0 236 203 153 316 311 252 458 384 258 349 142 197 113 261 310 232 110
#  123 170 369 152 244 165 337 300 333 385 322 564 239 293 407 149 199 417
# ...

# %%
uni5 = heart["RestingECG"].unique()
print("RestingECG columns unique values are::")
print("------------------------------------------------------------------------")
print(uni5)
# Out:
# RestingECG columns unique values are::
# ------------------------------------------------------------------------
# ['Normal' 'ST' 'LVH']

# %%
uni6 = heart["ExerciseAngina"].unique()
print("ExerciseAngina columns unique values are::")
print("------------------------------------------------------------------------")
print(uni6)
# Out:
# ExerciseAngina columns unique values are::
# ------------------------------------------------------------------------
# ['N' 'Y']

# %% [markdown]
# # 2. value_counts = It is used to check values with its count for particular col.

# %%
count1 = heart["Sex"].value_counts()
print("Sex column value counts::")
print("...........................")
print(count1)
# Out:
# Sex column value counts::
# ...........................
# M    725
# F    193
# Name: Sex, dtype: int64

# %%
count2 = heart["ChestPainType"].value_counts()
print("ChestPainType column value counts::")
print("....................................")
print(count2)
# Out:
# ChestPainType column value counts::
# ....................................
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
count3 = heart["RestingBP"].value_counts()
print("RestingBP column value counts::")
print("....................................")
print(count3)
# Out:
# RestingBP column value counts::
# ....................................
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
#       ...
# 113      1
# 164      1
# 117      1
# 127      1
# 0        1
# Name: RestingBP, Length: 67, dtype: int64

# %%
count4 = heart["RestingECG"].value_counts()
print("RestingECG column value counts::")
print("....................................")
print(count4)
# Out:
# RestingECG column value counts::
# ....................................
# Normal    552
# LVH       188
# ST        178
# Name: RestingECG, dtype: int64

# %%
count5 = heart["ST_Slope"].value_counts()
print("ST_Slope column value counts::")
print("....................................")
print(count5)
# Out:
# ST_Slope column value counts::
# ....................................
# Flat    460
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64

# %%
count6 = heart["HeartDisease"].value_counts()
print("HeartDisease column value counts::")
print("....................................")
print(count6)
# Out:
# HeartDisease column value counts::
# ....................................
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %% [markdown]
# # 3. iloc = It is based on indexing used for slicing the data

# %% [markdown]
# # a. select rows with indices using iloc

# %%
heart.iloc[[0,2]]
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 2   37   M           ATA        130          283          0         ST     98
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 2              N      0.0       Up             0

# %%
heart.iloc[[3,9]]
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 3   48   F           ASY        138          214          0     Normal    108
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 3              Y      1.5     Flat             1
# 9              N      0.0       Up             0

# %%
heart.iloc[[900,101]]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 900   58   M           ASY        114          318          0         ST
# 101   51   M           ASY        130          179          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 900    140              N      4.4     Down             1
# 101    100              N      0.0       Up             0

# %% [markdown]
# # b. select rows with particular indices & columns

# %%
h1 = heart.iloc[[0,2],[1,3]]
print("1st square bracket [0,2] indicates rows numbers")
print("2nd square bracket [1,3] indicates column numbers")
print("-------------------------------------------------------")
print(h1)
# Out:
# 1st square bracket [0,2] indicates rows numbers
# 2nd square bracket [1,3] indicates column numbers
# -------------------------------------------------------
#   Sex  RestingBP
# 0   M        140
# 2   M        130

# %%
h2 = heart.iloc[[4,5],[3,4]]
print("1st square bracket [4,5] indicates rows numbers")
print("2nd square bracket [3,4] indicates column numbers")
print("-------------------------------------------------------")
print(h2)
# Out:
# 1st square bracket [4,5] indicates rows numbers
# 2nd square bracket [3,4] indicates column numbers
# -------------------------------------------------------
#    RestingBP  Cholesterol
# 4        150          195
# 5        120          339

# %%
h3 = heart.iloc[[300,400],[3,4]]
print("1st square bracket [300,400] indicates rows numbers")
print("2nd square bracket [3,4] indicates column numbers")
print("-------------------------------------------------------")
print(h3)
# Out:
# 1st square bracket [300,400] indicates rows numbers
# 2nd square bracket [3,4] indicates column numbers
# -------------------------------------------------------
#      RestingBP  Cholesterol
# 300        160            0
# 400        160            0

# %% [markdown]
# # c. select a range of rows using iloc

# %%
a1 = heart.iloc[0:3]
print("slice the data 0 to 3 rows")
print("------------------------------")
a1
# Out:
# slice the data 0 to 3 rows
# ------------------------------
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0

# %%
a2 = heart.iloc[0:50]
print("slice the data 0 to 50 rows")
print("------------------------------")
a2
# Out:
# slice the data 0 to 50 rows
# ------------------------------
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# ...

# %% [markdown]
# # d. select a range of rows & columns using iloc

# %%
b1 = heart.iloc[0:20,2:6]
print("slice the data 0 to 20 rows && 2 to 6 columns")
print("----------------------------------------------")
b1
# Out:
# slice the data 0 to 20 rows && 2 to 6 columns
# ----------------------------------------------
#    ChestPainType  RestingBP  Cholesterol  FastingBS
# 0            ATA        140          289          0
# 1            NAP        160          180          0
# 2            ATA        130          283          0
# 3            ASY        138          214          0
# 4            NAP        150          195          0
# 5            NAP        120          339          0
# 6            ATA        130          237          0
# 7            ATA        110          208          0
# 8            ASY        140          207          0
# 9            ATA        120          284          0
# 10           NAP        130          211          0
# 11           ATA        136          164          0
# 12           ATA        120          204          0
# 13           ASY        140          234          0
# 14           NAP        115          211          0
# ...

# %%
b2 = heart.iloc[0:10,0:5]
print("slice the data 0 to 10 rows && 0 to 5 columns")
print("----------------------------------------------")
b2
# Out:
# slice the data 0 to 10 rows && 0 to 5 columns
# ----------------------------------------------
#    Age Sex ChestPainType  RestingBP  Cholesterol
# 0   40   M           ATA        140          289
# 1   49   F           NAP        160          180
# 2   37   M           ATA        130          283
# 3   48   F           ASY        138          214
# 4   54   M           NAP        150          195
# 5   39   M           NAP        120          339
# 6   45   F           ATA        130          237
# 7   54   M           ATA        110          208
# 8   37   M           ASY        140          207
# 9   48   F           ATA        120          284
