# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Acer\Desktop\Dataset\heart_disease dataset.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ## Normalization

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # 1) Min-Max Scaler.Normalization

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
x_train_scale=mn.fit_transform(x_train)
x_test_scale=mn.fit_transform(x_test)

# %%
print(x_train_scale)
# Out:
# [[0.27083333 1.         1.         ... 1.         0.5        0.66666667]
#  [0.77083333 0.         0.66666667 ... 0.5        0.25       0.66666667]
#  [0.5        1.         0.66666667 ... 1.         0.75       0.66666667]
#  ...
#  [0.75       1.         1.         ... 0.5        0.25       0.66666667]
#  [0.79166667 1.         0.         ... 0.5        0.         0.66666667]
#  [0.64583333 1.         0.66666667 ... 0.5        0.         0.66666667]]

# %%
print(x_test_scale)
# Out:
# [[0.31914894 1.         0.66666667 ... 1.         0.         0.66666667]
#  [0.61702128 0.         0.33333333 ... 1.         0.5        0.66666667]
#  [0.72340426 1.         0.         ... 1.         0.5        1.        ]
#  ...
#  [0.29787234 0.         0.66666667 ... 0.5        0.         0.66666667]
#  [0.78723404 0.         0.         ... 0.5        0.5        1.        ]
#  [0.89361702 0.         0.         ... 0.5        0.         0.66666667]]

# %%
print(np.min(x_train_scale)," ",np.max(x_train_scale))
# Out:
# 0.0   1.0

# %% [markdown]
# # 2) MaxAbsScaler.Normalization

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
x1=data.iloc[:,:-1].values
y1=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import MaxAbsScaler
mn1=MaxAbsScaler()
x1_train_scale=mn1.fit_transform(x_train)
x1_test_scale=mn1.fit_transform(x_test)

# %%
print(np.min(x1_train_scale)," ",np.max(x1_train_scale))
# Out:
# 0.0   1.0

# %% [markdown]
# # 3) Robust Scaler

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
x2=data.iloc[:,:-1].values
y2=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x2,y2,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import RobustScaler
rb=RobustScaler()

# %%
x2_train_scale=rb.fit(x_train)
x2_test_scale=rb.fit(x_test)

# %%
print(np.min(x2_train_scale)," ",np.max(x2_train_scale))
# Out:
# RobustScaler()   RobustScaler()

# %%
print(x2_train_scale)
# Out:
# RobustScaler()
