# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\Acer\Desktop\Dataset\HousePrice.csv")

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# # 1) find the owner's data those are having under 50 lac. with rera approved ?

# %%
data=dataset.loc[(dataset["POSTED_BY"]=="Owner") & (dataset["TARGET(PRICE_IN_LACS)"]<=50.0) & (dataset["RERA"]==1)]
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 9         Owner                   0     1        2       BHK   879.120879
# 100       Owner                   1     1        2       BHK   989.902989
# 122       Owner                   1     1        2       BHK  1109.165207
# 128       Owner                   0     1        2       BHK   398.262129
# 282       Owner                   0     1        2       BHK   945.179584
# ...         ...                 ...   ...      ...       ...          ...
# 29340     Owner                   0     1        2       BHK  1000.000000
# 29360     Owner                   1     1        2       BHK  1090.159104
# 29377     Owner                   0     1        2       BHK   953.389831
# 29407     Owner                   0     1        3       BHK  1463.679075
# 29416     Owner                   0     1        1       BHK   550.055005
#
#        READY_TO_MOVE  RESALE                        ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# # 2) find the count of rera approved plot the data on seaborn

# %%
sns.countplot(x="RERA",data=dataset)
# Out:
# <AxesSubplot:xlabel='RERA', ylabel='count'>

# %% [markdown]
# # 3) How to reduce two precision in SQUARE_FT

# %%
dataset["SQUARE_FT"].round(2)
# Out:
# 0        1300.24
# 1        1275.00
# 2         933.16
# 3         929.92
# 4         999.01
#           ...
# 29446    2500.00
# 29447     769.23
# 29448    1022.64
# 29449     927.08
# 29450     896.77
# Name: SQUARE_FT, Length: 29451, dtype: float64

# %% [markdown]
# # 4) slice the cities also bangalore data. find how many bangalore cities flats those are rera approved ?

# %%
dataset=pd.read_csv(r"C:\Users\Acer\Desktop\Dataset\HousePrice.csv")
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset["ADDRESS"]=dataset["ADDRESS"].str.split(",").str.get(1)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
d1=dataset.rename(columns={"ADDRESS":"city_name"})
d1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE             city_name  LONGITUDE   LATITUDE  \
# ...

# %%
d1.loc[(d1["city_name"]=="Bangalore") & (d1["RERA"]==1)]
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 8        Dealer                   0     1        2       BHK  1040.000000
# 17       Dealer                   1     1        3       BHK  2124.896706
# 19       Dealer                   0     1        3       BHK  2178.649237
# 163      Dealer                   1     1        4       BHK  2636.296531
# 180      Dealer                   1     1        2       BHK  1301.894980
# ...         ...                 ...   ...      ...       ...          ...
# 29369    Dealer                   1     1        4       BHK  2174.908425
# 29386    Dealer                   0     1        3       BHK  1727.115717
# 29402    Dealer                   0     1        2       BHK  1015.977770
# 29404    Dealer                   0     1        2       BHK   942.269409
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE  city_name  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# # 5) Increase the target price by 10 lac then decrease the bangalore target price        by 5 lac

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
col=[]
for x in dataset["TARGET(PRICE_IN_LACS)"]:
    x1=x+10
    col.append(x1)
dataset.insert(12,"Price_1",col)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
d2=dataset.loc[dataset["ADDRESS"]=="Bangalore"]
d2
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 8        Dealer                   0     1        2       BHK  1040.000000
# 11       Dealer                   0     0        2       BHK  1333.010179
# 12        Owner                   0     0        2       BHK   927.177902
# ...         ...                 ...   ...      ...       ...          ...
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE    ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
col1=[]
for x in d2["Price_1"]:
    x1=x-5
    col1.append(x1)
d2.insert(13,"Price_2",col1)

# %%
d2.round(2)
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  SQUARE_FT  \
# 0         Owner                   0     0        2       BHK    1300.24
# 2         Owner                   0     0        2       BHK     933.16
# 8        Dealer                   0     1        2       BHK    1040.00
# 11       Dealer                   0     0        2       BHK    1333.01
# 12        Owner                   0     0        2       BHK     927.18
# ...         ...                 ...   ...      ...       ...        ...
# 29408    Dealer                   0     0        2       BHK    1105.85
# 29415     Owner                   0     0        4       BHK    3650.24
# 29421    Dealer                   0     0        2       BHK    1409.06
# 29433     Owner                   0     0        2       BHK    1195.03
# 29436     Owner                   1     1        2       BHK    1175.13
#
#        READY_TO_MOVE  RESALE    ADDRESS  LONGITUDE  LATITUDE  \
# ...
