# %%
import numpy as np
import pandas as pd

# %%
heart = pd.read_csv(r"C:\Users\Kajal\Desktop\ssd\Desktop\dataset work November\datasets\heart.csv")
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
heart.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
heart.isnull().any()
# Out:
# Age               False
# Sex               False
# ChestPainType     False
# RestingBP         False
# Cholesterol       False
# FastingBS         False
# RestingECG        False
# MaxHR             False
# ExerciseAngina    False
# Oldpeak           False
# ST_Slope          False
# HeartDisease      False
# dtype: bool

# %%
heart.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # loc = It is based on conditions for slicing the data

# %% [markdown]
# # a. all th rows based on any condition in a column

# %%
## find out the age is less than equal to 40

# %%
age1 = heart.loc[heart.Age<=40]
age1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 5     39   M           NAP        120          339          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 10    37   F           NAP        130          211          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 846   39   M           ASY        118          219          0     Normal
# 856   39   M           NAP        140          321          0        LVH
# 892   39   F           NAP        138          220          0     Normal
# 898   35   M           ATA        122          192          0     Normal
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
age1["Age"].min()
# Out:
# 28

# %%
age1["Age"].max()
# Out:
# 40

# %%
## find the BP rate is 140

# %%
bp = heart.loc[heart.RestingBP==140]
bp
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 13    49   M           ASY        140          234          0     Normal
# 36    65   M           ASY        140          306          1     Normal
# 43    52   M           NAP        140          259          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 873   64   M           NAP        140          335          0     Normal
# 882   56   F           ATA        140          294          0        LVH
# 883   57   M           ASY        140          192          0     Normal
# 908   63   M           ASY        140          187          0        LVH
# 912   57   F           ASY        140          241          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
bp["RestingBP"].min()
# Out:
# 140

# %%
bp["RestingBP"].max()
# Out:
# 140

# %% [markdown]
# # b. find all the rows with more than one condition

# %%
## find out male age is less than 30

# %%
h1 = heart[['Age','Sex']]
h1
# Out:
#      Age Sex
# 0     40   M
# 1     49   F
# 2     37   M
# 3     48   F
# 4     54   M
# ..   ...  ..
# 913   45   M
# 914   68   M
# 915   57   M
# 916   57   F
# 917   38   M
#
# [918 rows x 2 columns]

# %%
h2 = h1.loc[(h1.Age<=30) & (h1.Sex=='M')]
h2
# Out:
#      Age Sex
# 170   29   M
# 208   28   M
# 219   29   M
# 829   29   M

# %% [markdown]
# # c. select range of rows using loc

# %%
a1 = heart.loc[200:210]
a1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 200   47   M            TA        110          249          0     Normal
# 201   46   M           NAP        120          230          0     Normal
# 202   42   M           NAP        160          147          0     Normal
# 203   31   F           ATA        100          219          0         ST
# 204   56   M           ATA        130          184          0     Normal
# 205   50   M           ASY        150          215          0     Normal
# 206   35   M           ATA        120          308          0        LVH
# 207   35   M           ATA        110          257          0     Normal
# 208   28   M           ATA        130          132          0        LVH
# 209   54   M           ASY        125          216          0     Normal
# 210   48   M           ASY        106          263          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
a2 = heart.loc[50:55]
a2
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 50   50   M           ASY        130          233          0     Normal
# 51   47   F           ASY        120          205          0     Normal
# 52   45   M           ATA        140          224          1     Normal
# 53   41   F           ATA        130          245          0     Normal
# 54   52   F           ASY        130          180          0     Normal
# 55   51   F           ATA        160          194          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 50    121              Y      2.0     Flat             1
# 51     98              Y      2.0     Flat             1
# 52    122              N      0.0       Up             0
# 53    150              N      0.0       Up             0
# 54    140              Y      1.5     Flat             0
# 55    170              N      0.0       Up             0

# %% [markdown]
# # d.select only required columns with a condition

# %%
row = heart.loc[(heart.Age>=40),['Age']]
row
# Out:
#      Age
# 0     40
# 1     49
# 3     48
# 4     54
# 6     45
# ..   ...
# 912   57
# 913   45
# 914   68
# 915   57
# 916   57
#
# [838 rows x 1 columns]
