# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\Acer\Desktop\Dataset\HousePrice.csv").round(2)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  SQUARE_FT  \
# 0         Owner                   0     0        2       BHK    1300.24
# 1        Dealer                   0     0        2       BHK    1275.00
# 2         Owner                   0     0        2       BHK     933.16
# 3         Owner                   0     1        2       BHK     929.92
# 4        Dealer                   1     0        2       BHK     999.01
# ...         ...                 ...   ...      ...       ...        ...
# 29446     Owner                   0     0        3       BHK    2500.00
# 29447     Owner                   0     0        2       BHK     769.23
# 29448    Dealer                   0     0        2       BHK    1022.64
# 29449     Owner                   0     0        2       BHK     927.08
# 29450    Dealer                   0     1        2       BHK     896.77
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
data=dataset.loc[dataset["TARGET(PRICE_IN_LACS)"]<=20.0]
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  SQUARE_FT  \
# 14        Owner                   0     0        1       BHK     649.98
# 29       Dealer                   0     0        2       BHK    1000.00
# 97        Owner                   0     0        2       BHK     900.00
# 105       Owner                   0     0        1       BHK     483.09
# 128       Owner                   0     1        2       BHK     398.26
# ...         ...                 ...   ...      ...       ...        ...
# 29416     Owner                   0     1        1       BHK     550.06
# 29422     Owner                   0     0        2       BHK     646.99
# 29424     Owner                   0     0        1       BHK     632.07
# 29427     Owner                   0     0        2       BHK    1200.00
# 29447     Owner                   0     0        2       BHK     769.23
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
sns.set(style="darkgrid")

# %%
sns.catplot(x="POSTED_BY",y="TARGET(PRICE_IN_LACS)",data=data,hue="RERA",kind="swarm")
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 64.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="POSTED_BY",y="TARGET(PRICE_IN_LACS)",data=data,hue="BHK_NO.",kind="strip")

# %%
sns.catplot(x="POSTED_BY",y="TARGET(PRICE_IN_LACS)",data=data,hue="BHK_NO.",kind="swarm")
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 64.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="POSTED_BY",y="TARGET(PRICE_IN_LACS)",data=data,hue="READY_TO_MOVE",kind="swarm",col="BHK_NO.",col_wrap=3)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 42.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
