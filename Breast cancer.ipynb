# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Acer\Documents\Edubridge\BreastCancer.csv")

# %%
data
# Out:
#      Unnamed: 0       Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 0             1  1000025             5          1           1              1
# 1             2  1002945             5          4           4              5
# 2             3  1015425             3          1           1              1
# 3             4  1016277             6          8           8              1
# 4             5  1017023             4          1           1              3
# ..          ...      ...           ...        ...         ...            ...
# 694         695   776715             3          1           1              1
# 695         696   841769             2          1           1              1
# 696         697   888820             5         10          10              3
# 697         698   897471             4          8           6              4
# 698         699   897471             4          8           8              5
#
# ...

# %%
data.head()
# Out:
#    Unnamed: 0       Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 0           1  1000025             5          1           1              1
# 1           2  1002945             5          4           4              5
# 2           3  1015425             3          1           1              1
# 3           4  1016277             6          8           8              1
# 4           5  1017023             4          1           1              3
#
#    Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses   Class
# 0             2          1.0            3                1        1  benign
# 1             7         10.0            3                2        1  benign
# 2             2          2.0            3                1        1  benign
# 3             3          4.0            3                7        1  benign
# 4             2          1.0            3                1        1  benign

# %%
data.tail()
# Out:
#      Unnamed: 0      Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 694         695  776715             3          1           1              1
# 695         696  841769             2          1           1              1
# 696         697  888820             5         10          10              3
# 697         698  897471             4          8           6              4
# 698         699  897471             4          8           8              5
#
#      Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses  \
# 694             3          2.0            1                1        1
# 695             2          1.0            1                1        1
# 696             7          3.0            8               10        2
# 697             3          4.0           10                6        1
# 698             4          5.0           10                4        1
#
#          Class
# 694     benign
# 695     benign
# 696  malignant
# 697  malignant
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0            Id  Cl.thickness   Cell.size  Cell.shape  \
# count  699.000000  6.990000e+02    699.000000  699.000000  699.000000
# mean   350.000000  1.071704e+06      4.417740    3.134478    3.207439
# std    201.928205  6.170957e+05      2.815741    3.051459    2.971913
# min      1.000000  6.163400e+04      1.000000    1.000000    1.000000
# 25%    175.500000  8.706885e+05      2.000000    1.000000    1.000000
# 50%    350.000000  1.171710e+06      4.000000    1.000000    1.000000
# 75%    524.500000  1.238298e+06      6.000000    5.000000    5.000000
# max    699.000000  1.345435e+07     10.000000   10.000000   10.000000
#
#        Marg.adhesion  Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  \
# count     699.000000    699.000000   683.000000   699.000000       699.000000
# mean        2.806867      3.216023     3.544656     3.437768         2.866953
# std         2.855379      2.214300     3.643857     2.438364         3.053634
# ...

# %%
data.shape
# Out:
# (699, 12)

# %%
data=data.rename(columns={"Unnamed: 0":"Unnamed","Cl.thickness":"thickness","Cell.size":"Cellsize","Cell.shape":"Cellshape","Marg.adhesion":"Margadhesion","Epith.c.size":"Epithsize","Bare.nuclei":"Barenuclei","Bl.cromatin":"Blcromatin","Normal.nucleoli":"Normalnucleoli"})

# %%
data
# Out:
#      Unnamed       Id  thickness  Cellsize  Cellshape  Margadhesion  \
# 0          1  1000025          5         1          1             1
# 1          2  1002945          5         4          4             5
# 2          3  1015425          3         1          1             1
# 3          4  1016277          6         8          8             1
# 4          5  1017023          4         1          1             3
# ..       ...      ...        ...       ...        ...           ...
# 694      695   776715          3         1          1             1
# 695      696   841769          2         1          1             1
# 696      697   888820          5        10         10             3
# 697      698   897471          4         8          6             4
# 698      699   897471          4         8          8             5
#
#      Epithsize  Barenuclei  Blcromatin  Normalnucleoli  Mitoses      Class
# 0            2         1.0           3               1        1     benign
# ...

# %%
data.dtypes
# Out:
# Unnamed             int64
# Id                  int64
# thickness           int64
# Cellsize            int64
# Cellshape           int64
# Margadhesion        int64
# Epithsize           int64
# Barenuclei        float64
# Blcromatin          int64
# Normalnucleoli      int64
# Mitoses             int64
# Class              object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Unnamed            0
# Id                 0
# thickness          0
# Cellsize           0
# Cellshape          0
# Margadhesion       0
# Epithsize          0
# Barenuclei        16
# Blcromatin         0
# Normalnucleoli     0
# Mitoses            0
# Class              0
# dtype: int64

# %%
data.Barenuclei.value_counts()
# Out:
# 1.0     402
# 10.0    132
# 2.0      30
# 5.0      30
# 3.0      28
# 8.0      21
# 4.0      19
# 9.0       9
# 7.0       8
# 6.0       4
# Name: Barenuclei, dtype: int64

# %%
data["Barenuclei"]=data["Barenuclei"].fillna(6.0)

# %%
data.isnull().sum()
# Out:
# Unnamed           0
# Id                0
# thickness         0
# Cellsize          0
# Cellshape         0
# Margadhesion      0
# Epithsize         0
# Barenuclei        0
# Blcromatin        0
# Normalnucleoli    0
# Mitoses           0
# Class             0
# dtype: int64

# %%
data["Class"].value_counts()
# Out:
# benign       458
# malignant    241
# Name: Class, dtype: int64

# %%
data["Class"].replace({"benign":0,"malignant":1},inplace=True)

# %%
data.dtypes
# Out:
# Unnamed             int64
# Id                  int64
# thickness           int64
# Cellsize            int64
# Cellshape           int64
# Margadhesion        int64
# Epithsize           int64
# Barenuclei        float64
# Blcromatin          int64
# Normalnucleoli      int64
# Mitoses             int64
# Class               int64
# dtype: object

# %%
data.shape
# Out:
# (699, 12)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (699, 12)

# %%
data1=data.corr()

# %%
data1
# Out:
#                  Unnamed        Id  thickness  Cellsize  Cellshape  \
# Unnamed         1.000000  0.079120  -0.125619 -0.099063  -0.119104
# Id              0.079120  1.000000  -0.055308 -0.041603  -0.041576
# thickness      -0.125619 -0.055308   1.000000  0.644913   0.654589
# Cellsize       -0.099063 -0.041603   0.644913  1.000000   0.906882
# Cellshape      -0.119104 -0.041576   0.654589  0.906882   1.000000
# Margadhesion   -0.056690 -0.064878   0.486356  0.705582   0.683079
# Epithsize      -0.186679 -0.045528   0.521816  0.751799   0.719668
# Barenuclei     -0.192132 -0.103552   0.578510  0.679704   0.704203
# Blcromatin     -0.147196 -0.060051   0.558428  0.755721   0.735948
# Normalnucleoli -0.149697 -0.052072   0.535835  0.722865   0.719446
# Mitoses        -0.134098 -0.034901   0.350034  0.458693   0.438911
# Class          -0.195603 -0.080226   0.716001  0.817904   0.818934
#
#                 Margadhesion  Epithsize  Barenuclei  Blcromatin  \
# ...

# %%
plt.figure(figsize=(15,10))
heatmap=sns.heatmap(data1,linewidth=1,annot=True,cmap=plt.cm.Blues)
plt.title("Heatmap using Seaborn Method")
plt.show()

# %%
#visualisation and plots (count plot) sub/bar plot ax is axis
fig,ax=plt.subplots(2,5,figsize=(16,10))

sns.countplot("Blcromatin",data=data,ax=ax[0][0])
sns.countplot("Normalnucleoli",data=data,ax=ax[0][1])
sns.countplot("thickness",data=data,ax=ax[0][2])
sns.countplot("Cellsize",data=data,ax=ax[0][3])
sns.countplot("Cellshape",data=data,ax=ax[0][4])
sns.countplot("Margadhesion",data=data,ax=ax[1][0])
sns.countplot("Epithsize",data=data,ax=ax[1][1])
sns.countplot("Barenuclei",data=data,ax=ax[1][2])
sns.countplot("Mitoses",data=data,ax=ax[1][3])
sns.countplot("Class",data=data,ax=ax[1][4])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
data.boxplot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data.Mitoses.hist() #Rightly skewed #mitosis is a categorical variable we cant remove outliers of categorical variable
# Out:
# <AxesSubplot:>

# %%
iqr=data.Mitoses.quantile(0.75)-data.Mitoses.quantile(0.25)
iqr
# Out:
# 0.0

# %%
data.boxplot(column="Mitoses") #for categorical variable box plot is like straight line
# Out:
# <AxesSubplot:>
